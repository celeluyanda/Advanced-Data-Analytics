-- %%
CREATE SCHEMA IF NOT EXISTS my_coffee_shop 
    COMMENT 'Bright Coffee Shop analytics schema'; 
  
USE my_coffee_shop; 
  
SELECT current_database();
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_database()</th></tr></thead><tbody><tr><td>my_coffee_shop</td></tr></tbody></table></div>

-- %%
create table if not exists dim_customers ( 
    customer_id bigint  primary key NOT null,
    First_name string not null, 
    Last_name string Not null, 
    email string, 
    Tier string,
    Loyalty_points int
);
create table if not exists dim_products ( 
    Product_id bigint Primary Key NOT NULL,
    Product_Code String, 
    Product_name string, 
    Price decimal (8,2), 
    Category string, 
    is_active boolean
); 

create table if not exists Fact_Orders (
    0rder_id bigint Not null,
    Customer_id bigint not null,
    Product_id bigint not null, 
    store_id bigint not null,
    Order_date date not null, 
    Quantity Int not null, 
    Unit_Price decimal(8,2) NOT NULL, 
    Total_amount decimal (10,2) not null)
using Delta PARTITIONED BY (Order_date);

-- %%
ALTER TABLE dim_customers 
    SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name','delta.minReaderVersion'   
= '2','delta.minWriterVersion'   = '5'); 
ALTER TABLE dim_customers RENAME COLUMN Loyalty_points to Points;
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-5644759989959645>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', "ALTER TABLE dim_customers \n    SET TBLPROPERTIES ('delta.columnMapping.mode' = 'name','delta.minReaderVersion'   \n= '2','delta.minWriterVersion'   = '5'); \nALTER TABLE dim_customers RENAME COLUMN Loyalty_points to Points; \n")
--
-- File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
-- ...

-- %%
INSERT INTO dim_customers (customer_id, First_name, Last_name, email, Tier, Points)
values (1, 'Liyanda','Cele','celeluyanda@gmail.com','Gold','1'),
(2, 'Bongumusa', 'Ngcobo','bongumusa65@gmail.com','Silver','2'),
(3, 'Mbali','Khumbuza','Khumbuzam@yahoo.com','Bronze','3'),
(4,'Karabo','Mohale','kjmohale2@gmail.com','Gold','1'),
(5, 'Kyle','Growdon','Kgrowdon@gmail.com','Bronze','3');
SELECT * FROM dim_customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
INSERT INTO dim_products (Product_id, Product_Code, Product_name, Price, Category, is_active)
values 
(1,'TE01','Green Tea','2.54','Tea','True'),
(2,'TE02','Black Tea','2.90','Tea','True'),
(3,'CO01','Cappuccino','3.50','Coffee','True'),
(4,'FO01','Blueberry Muffin','4.99','Food','False'),
(5,'FO02','Chocolate Muffin','4.99','Food','True');
select * from dim_products;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
SELECT customer_id, First_name, Tier, Points 
FROM   dim_customers 
WHERE  tier = 'Bronze'; 

UPDATE dim_customers 
SET    Points = points + 50 
WHERE  Tier = 'Bronze'; 

SELECT customer_id, First_name, Tier, Points 
FROM   dim_customers 
WHERE  tier = 'Bronze';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>First_name</th><th>Tier</th><th>Points</th></tr></thead><tbody><tr><td>3</td><td>Mbali</td><td>Bronze</td><td>53</td></tr><tr><td>5</td><td>Kyle</td><td>Bronze</td><td>53</td></tr><tr><td>3</td><td>Mbali</td><td>Bronze</td><td>53</td></tr><tr><td>5</td><td>Kyle</td><td>Bronze</td><td>53</td></tr></tbody></table></div>

-- %%
CREATE TABLE dim_customers_backup AS SELECT * FROM dim_customers; 
SELECT * FROM dim_customers WHERE customer_id = 3; 
delete from dim_customers where customer_id = 3; 
select * from dim_customers; 
describe history dim_customers;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
